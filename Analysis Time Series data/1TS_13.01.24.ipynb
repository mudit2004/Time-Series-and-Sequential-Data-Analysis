# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
series = pd.read_csv(r'daily_total_female_births_in_cal.csv', header=0, parse_dates=[0],index_col=0,)

# %%
print(type(series))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(series.head())
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44

# %%
print(series.head(10))
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# 1959-01-06      29
# 1959-01-07      45
# 1959-01-08      43
# 1959-01-09      38
# 1959-01-10      27

# %%
print(series.tail(5))
# Out:
#             Births
# Date
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50

# %%
print(series.size)
# Out:
# 365

# %%
series.index = pd.to_datetime(series.index)
january_data = series[series.index.month == 1]
print(january_data)
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# 1959-01-06      29
# 1959-01-07      45
# 1959-01-08      43
# 1959-01-09      38
# 1959-01-10      27
# 1959-01-11      38
# 1959-01-12      33
# 1959-01-13      55
# 1959-01-14      47
# 1959-01-15      45
# 1959-01-16      37
# 1959-01-17      50
# 1959-01-18      43
# 1959-01-19      41
# 1959-01-20      52
# 1959-01-21      34
# 1959-01-22      53
# 1959-01-23      39
# 1959-01-24      32
# 1959-01-25      37
# 1959-01-26      43
# 1959-01-27      39
# 1959-01-28      35
# 1959-01-29      44
# 1959-01-30      38
# 1959-01-31      24

# %%
print(series.describe())
# Out:
#            Births
# count  365.000000
# mean    41.980822
# std      7.348257
# min     23.000000
# 25%     37.000000
# 50%     42.000000
# 75%     46.000000
# max     73.000000

# %%
plt.figure(figsize=(10, 6)) 
plt.plot(series)
plt.show()

# %%
smoothed_series = series.rolling(window=7).mean()
plt.plot(smoothed_series)
plt.show()

# %%
smoothed_series = series.rolling(window=7).mean()
plt.plot(smoothed_series)
plt.xlabel('Date')
plt.ylabel('Number of Births')
plt.title('Births Over Time')
plt.show()
